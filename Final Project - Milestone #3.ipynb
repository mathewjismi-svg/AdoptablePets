# %% [markdown]
# # Final Project –  Adoptable Pets

# %% [markdown]
# ## Milestone 3

# %% [markdown]
# Jismi Mathew

# %% [markdown]
# 11/26/2025

# %% [markdown]
# Purpose: Clean the data, describe the cleaning steps taken and why, and show the cleaned data. Export the cleaned version into a new CSV file.

# %%
import pandas as pd

# %%
df = pd.read_csv("Adoptable_Pets.csv")

# %% [markdown]
# ### Look at data:

# %%
df.head()
# Out:
#   Animal ID Intake Type     In Date Pet name Animal Type  Pet Age Pet Size  \
# 0   A533749      RETURN  10/25/2025     JEFE         DOG  5 YEARS    LARGE
# 1   A536482   OWNER SUR  10/11/2025   BENITA       OTHER  4 YEARS      MED
# 2   A534659   OWNER SUR  08/17/2025    ETHAN         CAT   1 YEAR      MED
# 3   A536486   OWNER SUR  10/11/2025    PAPPY       OTHER  3 YEARS      MED
# 4   A531011   OWNER SUR  11/15/2025  *SAFIRA         CAT  2 YEARS      MED
#
#             Color                  Breed Sex  \
# 0     RED / WHITE  AM PIT BULL TER / MIX   N
# 1            GRAY              RABBIT SH   F
# 2    WHITE / GRAY            DOMESTIC SH   N
# 3           BROWN           SUGAR GLIDER   M
# 4  TORTIE / WHITE            DOMESTIC SH   S
#
#                                            URL Link  Crossing
# 0  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 1  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 2  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 3  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 4  http://www.petharbor.com/get_image.asp?res=DET...      NaN

# %% [markdown]
# ### Clean Column Names
# I cleaned the column names by converting them to lowercase and replacing spaces with underscores. This makes them easier to reference while coding.

# %%
df.columns = (
    df.columns
    .str.lower()
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

# %% [markdown]
# I made the names of some of the columns more simple for when referencing.

# %%
# Rename to simpler column names
df = df.rename(columns={
    "animal_id": "id",
    "pet_name": "name",
    "animal_type": "type",
    "pet_age": "age",
    "pet_size": "size",
    "url_link": "url"
})

# %%
#look at updated columns:
df.columns
# Out:
# Index(['id', 'intake_type', 'in_date', 'name', 'type', 'age', 'size', 'color',
#        'breed', 'sex', 'url', 'crossing'],
#       dtype='object')

# %% [markdown]
# ### Clean up text in certain columns

# %%
text_cols = ["name", "intake_type", "type", "size", "color", "breed", "sex"]

for col in text_cols:
    df[col] = df[col].astype(str).str.strip().str.title()

# %% [markdown]
# Check changes

# %%
df.head()
# Out:
#         id intake_type     in_date     name   type      age   size  \
# 0  A533749      Return  10/25/2025     Jefe    Dog  5 YEARS  Large
# 1  A536482   Owner Sur  10/11/2025   Benita  Other  4 YEARS    Med
# 2  A534659   Owner Sur  08/17/2025    Ethan    Cat   1 YEAR    Med
# 3  A536486   Owner Sur  10/11/2025    Pappy  Other  3 YEARS    Med
# 4  A531011   Owner Sur  11/15/2025  *Safira    Cat  2 YEARS    Med
#
#             color                  breed sex  \
# 0     Red / White  Am Pit Bull Ter / Mix   N
# 1            Gray              Rabbit Sh   F
# 2    White / Gray            Domestic Sh   N
# 3           Brown           Sugar Glider   M
# 4  Tortie / White            Domestic Sh   S
#
#                                                  url crossing
# 0  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 1  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 2  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 3  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 4  http://www.petharbor.com/get_image.asp?res=DET...      NaN

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# I looked for NaN values to understand which columns needed attention. Some fields had missing data, so I reviewed each to decide whether to fill, replace, or leave them.

# %%
df.isna().sum()
# Out:
# id              0
# intake_type     0
# in_date         0
# name            0
# type            0
# age             0
# size            0
# color           0
# breed           0
# sex             0
# url             0
# crossing       62
# dtype: int64

# %% [markdown]
# Check what is in the "crossing" column that is not an NaN value.

# %%
df[df['crossing'].notna()]
# Out:
#          id intake_type     in_date           name type       age   size  \
# 26  A537143       Stray  10/31/2025        *Wyclef  Cat   2 YEARS  Small
# 27  A536602       Stray  10/15/2025       *Axolotl  Cat   2 YEARS  Small
# 28  A537438       Stray  11/07/2025    *Jigglypuff  Cat   3 YEARS    Med
# 31  A512399       Stray  11/07/2025        Melanie  Cat   4 YEARS    Med
# 37  A537213       Stray  11/02/2025     *Mr Tuxedo  Dog   3 YEARS  Large
# 38  A537454       Stray  11/08/2025        *Holtby  Cat   2 YEARS    Med
# 42  A536891       Stray  10/23/2025        *Kismet  Cat   3 YEARS  Small
# 45  A537569       Stray  11/11/2025        *Rumpus  Cat   4 YEARS  Small
# 46  A535783       Stray  09/20/2025       *Maxwell  Cat  10 WEEKS  Small
# 47  A537675       Stray  11/14/2025       *Nutella  Dog   3 YEARS    Med
# 48  A536051       Stray  09/29/2025  *Burtonsville  Cat  14 WEEKS  Kitte
# 50  A536830       Stray  10/21/2025        *Foodie  Dog   2 YEARS    Med
# 51  A537099       Stray  10/29/2025         *Kevin  Dog   6 YEARS  Large
# 52  A536304       Stray  10/07/2025          *Fred  Dog   2 YEARS    Med
# 53  A537615       Stray  11/13/2025       *Pringle  Dog   9 YEARS    Med
#
#                 color                            breed sex  \
# 26              Black                      Domestic Sh   N
# 27  White / Brn Tabby                      Domestic Mh   N
# 28  Brn Tabby / White                      Domestic Sh   S
# 31          Brn Tabby                      Domestic Sh   S
# 37      Black / White                  Am Pit Bull Ter   N
# 38          Brn Tabby                      Domestic Sh   S
# 42      Black / White                      Domestic Mh   N
# 45          Brn Tabby                      Domestic Sh   N
# 46       Gray / White                      Domestic Sh   N
# 47              Brown                    Bulldog / Mix   S
# 48              Black                      Domestic Sh   S
# 50      Black / White                  Am Pit Bull Ter   N
# 51                Tan  Black Mouth Cur / Labrador Retr   N
# 52      Black / White                  Am Pit Bull Ter   N
# 53        Tan / White                  Am Pit Bull Ter   N
#
#                                                   url  \
# 26  http://www.petharbor.com/get_image.asp?res=DET...
# 27  http://www.petharbor.com/get_image.asp?res=DET...
# 28  http://www.petharbor.com/get_image.asp?res=DET...
# 31  http://www.petharbor.com/get_image.asp?res=DET...
# 37  http://www.petharbor.com/get_image.asp?res=DET...
# 38  http://www.petharbor.com/get_image.asp?res=DET...
# 42  http://www.petharbor.com/get_image.asp?res=DET...
# 45  http://www.petharbor.com/get_image.asp?res=DET...
# 46  http://www.petharbor.com/get_image.asp?res=DET...
# 47  http://www.petharbor.com/get_image.asp?res=DET...
# 48  http://www.petharbor.com/get_image.asp?res=DET...
# 50  http://www.petharbor.com/get_image.asp?res=DET...
# 51  http://www.petharbor.com/get_image.asp?res=DET...
# 52  http://www.petharbor.com/get_image.asp?res=DET...
# 53  http://www.petharbor.com/get_image.asp?res=DET...
#
#                                       crossing
# 26        0 ASHMONT CT, SILVER SPRING MD 20906
# 27   19900 APPLEDOWRE CIR, GERMANTOWN MD 20876
# 28      0 E DIAMOND AVE, GAITHERSBURG MD 20877
# 31       4300 FRANKFORT DR, ROCKVILLE MD 20853
# 37                 BEL PRE & ARTCTIC AVE 20853
# 38    2300 GREENERY LN, SILVER SPRING MD 20906
# 42                                ANNANDALE VA
# 45     8000 CRABTREE PL, GAITHERSBURG MD 20879
# 46      1200 SPRING ST, SILVER SPRING MD 20910
# 47      7800 CESSNA AVE, GAITHERSBURG MD 20879
# 48   14600 PERRYWOOD DR, BURTONSVILLE MD 20866
# 50             9800 MAIN ST, DAMASCUS MD 20872
# 51      18600 BROOKE RD, SANDY SPRING MD 20860
# 52  400 N FREDERICK AVE, GAITHERSBURG MD 20877
# 53       2900 JENNINGS RD, KENSINGTON MD 20895

# %% [markdown]
# ### Dropping the crossing column
# After seeing that NaN values only occur in the Crossing column and reviewing the data, the "crossing" column appears to contain pickup street addresses. I do not need this data to answer any of the research questions for this project. Because it also contains many empty entries and inconsistent formatting, I decided to drop it from the dataset.

# %%
df = df.drop(columns=["crossing"])

# %% [markdown]
# Check that the changes were made

# %%
df.columns
# Out:
# Index(['id', 'intake_type', 'in_date', 'name', 'type', 'age', 'size', 'color',
#        'breed', 'sex', 'url'],
#       dtype='object')

# %% [markdown]
# ### Check if any duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates.

# %% [markdown]
# #### Convert Age Column to Numeric Values rather than Strings

# %%
df["age"] = df["age"].str.extract(r"(\d+)").astype(float)

# %%
df['age']
# Out:
# 0      5.0
# 1      4.0
# 2      1.0
# 3      3.0
# 4      2.0
#       ...
# 72     4.0
# 73     6.0
# 74     1.0
# 75    14.0
# 76     4.0
# Name: age, Length: 77, dtype: float64

# %% [markdown]
# ### Save the Cleaned Data to a New CSV
# The cleaned dataset will be saved as `Adoptable_Pets_Cleaned.csv` so the original file remains untouched.

# %%
df.to_csv("Adoptable_Pets_Cleaned.csv", index=False)

# %%
cleaned_df = pd.read_csv("Adoptable_Pets_Cleaned.csv")

# %% [markdown]
# Verify data in new CSV is updated and correct

# %%
cleaned_df.head()
# Out:
#         id intake_type     in_date     name   type  age   size  \
# 0  A533749      Return  10/25/2025     Jefe    Dog  5.0  Large
# 1  A536482   Owner Sur  10/11/2025   Benita  Other  4.0    Med
# 2  A534659   Owner Sur  08/17/2025    Ethan    Cat  1.0    Med
# 3  A536486   Owner Sur  10/11/2025    Pappy  Other  3.0    Med
# 4  A531011   Owner Sur  11/15/2025  *Safira    Cat  2.0    Med
#
#             color                  breed sex  \
# 0     Red / White  Am Pit Bull Ter / Mix   N
# 1            Gray              Rabbit Sh   F
# 2    White / Gray            Domestic Sh   N
# 3           Brown           Sugar Glider   M
# 4  Tortie / White            Domestic Sh   S
#
#                                                  url
# 0  http://www.petharbor.com/get_image.asp?res=DET...
# 1  http://www.petharbor.com/get_image.asp?res=DET...
# 2  http://www.petharbor.com/get_image.asp?res=DET...
# 3  http://www.petharbor.com/get_image.asp?res=DET...
# 4  http://www.petharbor.com/get_image.asp?res=DET...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           77 non-null     object
#  1   intake_type  77 non-null     object
#  2   in_date      77 non-null     object
#  3   name         77 non-null     object
#  4   type         77 non-null     object
#  5   age          76 non-null     float64
#  6   size         77 non-null     object
#  7   color        77 non-null     object
#  8   breed        77 non-null     object
#  9   sex          77 non-null     object
#  10  url          77 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 6.7+ KB
