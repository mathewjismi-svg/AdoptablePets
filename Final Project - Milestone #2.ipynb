# %% [markdown]
# # Final Project –  Adoptable Pets

# %% [markdown]
# ## Milestone 2

# %% [markdown]
# Jismi Mathew

# %% [markdown]
# 11/26/2025

# %% [markdown]
# Purpose: Begin the data analysis process of your final project by collecting your data and doing some initial exploratory analysis.

# %%
import pandas as pd

# %%
df = pd.read_csv("Adoptable_Pets.csv")

# %% [markdown]
# Explore Data:

# %%
df.describe()
# Out:
#        Animal ID Intake Type     In Date Pet name Animal Type  Pet Age  \
# count         77          77          77       77          77       77
# unique        77           6          52       77           4       22
# top      A533749   OWNER SUR  11/18/2025     JEFE         CAT  2 YEARS
# freq           1          48           6        1          38       15
#
#        Pet Size          Color        Breed Sex  \
# count        77             77           77  77
# unique        6             30           25   5
# top         MED  BLACK / WHITE  DOMESTIC SH   N
# freq         44             14           31  40
#
#                                                 URL Link   \
# count                                                  77
# unique                                                 77
# top     http://www.petharbor.com/get_image.asp?res=DET...
# freq                                                    1
#
#                                     Crossing
# ...

# %%
df.columns
# Out:
# Index(['Animal ID', 'Intake Type', 'In Date', 'Pet name', 'Animal Type',
#        'Pet Age', 'Pet Size', 'Color', 'Breed', 'Sex', 'URL Link ',
#        'Crossing'],
#       dtype='object')

# %%
df.shape
# Out:
# (77, 12)

# %%
df.dtypes
# Out:
# Animal ID      object
# Intake Type    object
# In Date        object
# Pet name       object
# Animal Type    object
# Pet Age        object
# Pet Size       object
# Color          object
# Breed          object
# Sex            object
# URL Link       object
# Crossing       object
# dtype: object

# %%
df.head()
# Out:
#   Animal ID Intake Type     In Date Pet name Animal Type  Pet Age Pet Size  \
# 0   A533749      RETURN  10/25/2025     JEFE         DOG  5 YEARS    LARGE
# 1   A536482   OWNER SUR  10/11/2025   BENITA       OTHER  4 YEARS      MED
# 2   A534659   OWNER SUR  08/17/2025    ETHAN         CAT   1 YEAR      MED
# 3   A536486   OWNER SUR  10/11/2025    PAPPY       OTHER  3 YEARS      MED
# 4   A531011   OWNER SUR  11/15/2025  *SAFIRA         CAT  2 YEARS      MED
#
#             Color                  Breed Sex  \
# 0     RED / WHITE  AM PIT BULL TER / MIX   N
# 1            GRAY              RABBIT SH   F
# 2    WHITE / GRAY            DOMESTIC SH   N
# 3           BROWN           SUGAR GLIDER   M
# 4  TORTIE / WHITE            DOMESTIC SH   S
#
#                                            URL Link  Crossing
# 0  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 1  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# ...

# %%
df.tail()
# Out:
#    Animal ID Intake Type     In Date  Pet name Animal Type          Pet Age  \
# 72   A537254      RETURN  11/09/2025  SAMANTHA         CAT          4 YEARS
# 73   A486296   OWNER SUR  11/09/2025    WILLOW         CAT          6 YEARS
# 74   A522072   OWNER SUR  11/09/2025   *ANDREW         CAT  1 YEAR 5 MONTHS
# 75   A348332   OWNER SUR  09/05/2025  TIRAMISU         CAT         14 YEARS
# 76   A535978   OWNER SUR  09/26/2025      OREO         CAT          4 YEARS
#
#    Pet Size               Color        Breed Sex  \
# 72      MED                GRAY  DOMESTIC LH   S
# 73      MED           BRN TABBY  DOMESTIC SH   N
# 74      MED  ORANGE TAB / WHITE  DOMESTIC LH   N
# 75      MED   BRN TABBY / WHITE  DOMESTIC SH   S
# 76      MED       BLACK / WHITE  DOMESTIC SH   S
#
#                                             URL Link  Crossing
# 72  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# 73  http://www.petharbor.com/get_image.asp?res=DET...      NaN
# ...

# %%
df.sample(5)
# Out:
#    Animal ID Intake Type     In Date       Pet name Animal Type   Pet Age  \
# 24   A537652   OWNER SUR  11/14/2025          HAZEL         CAT  13 YEARS
# 48   A536051       STRAY  09/29/2025  *BURTONSVILLE         CAT  14 WEEKS
# 0    A533749      RETURN  10/25/2025           JEFE         DOG   5 YEARS
# 25   A537703   OWNER SUR  11/16/2025            SKU       OTHER    1 YEAR
# 4    A531011   OWNER SUR  11/15/2025        *SAFIRA         CAT   2 YEARS
#
#    Pet Size           Color                  Breed Sex  \
# 24      MED            GRAY            DOMESTIC SH   S
# 48    KITTE           BLACK            DOMESTIC SH   S
# 0     LARGE     RED / WHITE  AM PIT BULL TER / MIX   N
# 25      MED            GRAY                    RAT   M
# 4       MED  TORTIE / WHITE            DOMESTIC SH   S
#
#                                             URL Link   \
# 24  http://www.petharbor.com/get_image.asp?res=DET...
# 48  http://www.petharbor.com/get_image.asp?res=DET...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Animal ID    77 non-null     object
#  1   Intake Type  77 non-null     object
#  2   In Date      77 non-null     object
#  3   Pet name     77 non-null     object
#  4   Animal Type  77 non-null     object
#  5   Pet Age      77 non-null     object
#  6   Pet Size     77 non-null     object
#  7   Color        77 non-null     object
#  8   Breed        77 non-null     object
#  9   Sex          77 non-null     object
#  10  URL Link     77 non-null     object
#  11  Crossing     15 non-null     object
# dtypes: object(12)
# memory usage: 7.3+ KB
